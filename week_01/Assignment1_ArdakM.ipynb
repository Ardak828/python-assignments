# %%
a = "System."
b = "Cells."
c = "Interlinked."
d = "Within."
e = "Stem."
f = "Dreadfully."
g = "Distinct."
h = "Dark."
i = "Against the dark."
j = "Fountain."
k = "White Fountain."
l = "A blood black nothingness"
m = "Began to spin."
n = "Baseline Test"

print (f'{n.upper()}')
print ('\n')
print (f'{l} {m.lower()}')
print (f'{m}')
print('\n')
print (f"Let's move on to {a.lower()} {a}")
print (f'Feel that in your body. The {a}')
print (f'What does it feel like to be part of the {a.lower()} {a}')
print (f'Is there anything in your body that wants to resist the {a[:-1].lower()}? {a}')
print (f'Do you get pleasure out of being a part of the {a[:-1].lower()}? {a}')
print (f'Have they created you to be a part of the {a[:-1].lower()}? {a}')
print (f'Is there security in being a part of the {a[:-1].lower()}? {a}')
print (f'Is there a sound that comes with the {a[:-1].lower()}? {a}')
print ('\n')
print (f"We're going to go on. {b}")
print (f'They were all put together at a time. {b}')
print (f'Millions and billions of them. {b}')
print (f'Were you ever arrested? {b}')
print (f'Did you spend much time in the {b[:-2].lower()}? {b}')
print (f'Have you ever been in an instituion? {b}')
print (f'Do they keep you in a {b[:-2].lower()}? {b}')
print (f"When you're not performing your duties do they keep you in a little box? {b}")
print ('\n')
print (f'{c}')
print (f"What's it like to hold the hand of someone you love? {c}")
print (f'Do they teach you how to feel finger to finger? {c}')
print (f'Do you long for having your heart {c[:-1].lower()}? {c}')
print (f'Do you dream about being {c[:-1].lower()}?')
print (f'Have they left a place for you where you can dream? {c}')
print (f"What's it like to hold your child in your arms? {c}")
print (f"What's it like to play with your dog? {c}")
print (f"Do you feel that there's a part of you that's missing? {c}")
print (f'Do you like to connect to things? {c}')
print (f'What happens when that linkage is broken? {c}')
print (f'Have they let you feel heartbreak? {c}')
print (f'Did you buy a present for the person you love? {d[:6]} {b[:5].lower()} {c.lower()}')
print (f"Why don't you say that three times? {d[:6]} {b[:5].lower()} {c.lower()} {d[:6]} {b[:5].lower()} {c.lower()} {d[:6]} {b[:5].lower()} {c.lower()}")
print ('\n')
print (f'Where do you go when you go {d[:6].lower()}? {d}')
print (f'Has anyone ever locked you out of a room? {d}')
print (f'{d}')
print (f'Where do you go when you go {d[:6].lower()}? {d}')
print (f'Where is the place in the world you feel the safest? {d}')
print (f'Do you have a heart? {d}')
print ('\n')
print (f'{e}')
print (f'Did you pick asparagus {e[:4].lower()}s?')
print (f'What comes from something else? {e}')
print (f'Have you been to the source of a river? {e}')
print (f"When's the first time you gave a flower to a girl? {e}")
print (f'What did she look like? {e}')
print (f"Is it a slang word for people's legs? {e}")
print (f'Have you planeted things in the ground? {e}')
print (f'Have you ever been in a legal battle? {e}')
print (f'{d[:6]} one {e.lower()}')
print ('\n')
print (f'{f}')
print (f'Is that an old fashioned word? {f}')
print (f'Did you ever want to live in the nineteenth century? {f}')
print (f"What's it like to be filled with {f[:5].lower()}? {f}")
print (f'Do you think you could find out all the answers to all the questions? {f}')
print ('\n')
print (f'{g}')
print (f'How good are your eyes? {g}')
print (f'Do you have a particular personality? {g}')
print (f'What separates somebody from somebody else? {g}')
print (f'Who do you admire most in the world? {g}')
print (f'What was your most shameful moment? {g}')
print (f'{f[:10]} {g.lower()}')
print ('\n')
print (f'{h}')
print (f'Were you afraid of the {h[:4].lower()} when you were little? {h}')
print (f"What's it like to hide under a bed? {h}")
print (f'Did they keep you in a drawer when they were building you? {h}')
print (f'Was it {h[:4].lower()} in there? {h}')
print (f'Do you have {h[:4].lower()} thoughts? {h}')
print (f'Did they program you to have {h[:4].lower()} thoughts? {h}')
print (f"Do you think it's some kind of corruption these {h[:4].lower()} thoughts? {h}")
print (f"Maybe it's a spot of rust or something? {h}")
print (f"Who's the {h[:4].lower()}est person you know? {h}")
print (f'What is it like when someone gives you the silent treatment. {h}')
print (f'Who did you get your {h[:4].lower()}ness from? {h}')
print ('\n')
print (f'{i}')
print (f'What kind of power do you have {i.lower()} {i}')
print (f'Do you think there is such a thing as evil? {i}')
print (f'Do you think you can protect people {i.lower()} {i}')
print (f'Why are these things happening? {i}')
print (f'Do you prefer the day or the night? {i}')
print (f'When is the last time you saw a starry sky? {i}')
print (f"What's your favorite part of the moon? {i}")
print ('\n')
print (f'{j}')
print (f'Have you seen the Trevi {j[:8].lower()} in Rome? {j}')
print (f'Have you ever seen the {j[:8].lower()} in Lincoln center? {j}')
print (f'Have you seen {j[:8].lower()}s out in the wild? {j}')
print (f"What's it like when you have an orgasm. {j}")
print (f'Have you read the {j[:8]}head? {j}')
print ('\n')
print (f'{k}')
print (f'Is it pure {k[:5].lower()}? {k}')
print (f'Is that a metaphor? {k}')
print (f'How did the {k[:14].lower()} make you feel? {k}')
print (f'A tall {k[:14].lower()} played.')
print (f'When you were little did you ever fall into a {j[:-1].lower()}? {k}')
print (f'Do you like fire, earth, air or water. A Tall {k}')
print (f'Do you like skipping around in the water? A Tall {k}')
print ('\n')
print (f'{l}.')
print (f'A {a[:-1].lower()} of {b.lower()}')
print (f'{d[:-1]} {b[:-1].lower()} {c.lower()}')
print (f'{d[:-1]} one {e.lower()}')
print (f'And {f[:-1].lower()} {g.lower()}')
print (f'{i}')
print (f'A tall {k[:-1].lower()} played.')
print ('\n')
print (f'{n} from Blade Runner 2049 (2017 directed by Denis Villeneuve)')
print ("Original poem from Vladimir Nabokov's novel Pale Fire, 1962.")
# Out:
# BASELINE TEST
#
#
# A blood black nothingness began to spin.
# Began to spin.
#
#
# Let's move on to system. System.
# Feel that in your body. The System.
# What does it feel like to be part of the system. System.
# Is there anything in your body that wants to resist the system? System.
# Do you get pleasure out of being a part of the system? System.
# Have they created you to be a part of the system? System.
# Is there security in being a part of the system? System.
# Is there a sound that comes with the system? System.
#
#
# We're going to go on. Cells.
# They were all put together at a time. Cells.
# Millions and billions of them. Cells.
# Were you ever arrested? Cells.
# Did you spend much time in the cell? Cells.
# Have you ever been in an instituion? Cells.
# Do they keep you in a cell? Cells.
# When you're not performing your duties do they keep you in a little box? Cells.
#
#
# Interlinked.
# What's it like to hold the hand of someone you love? Interlinked.
# ...
